# %%
Solve[x^2-1==0, x]
# Out:
# <math><mrow><mo>{</mo> <mrow><mrow><mo>{</mo> <mrow><mi>x</mi> <mo>-&gt;</mo> <mtext>-1</mtext></mrow> <mo>}</mo></mrow> <mo>,</mo> <mrow><mo>{</mo> <mrow><mi>x</mi> <mo>-&gt;</mo> <mn>1</mn></mrow> <mo>}</mo></mrow></mrow> <mo>}</mo></mrow></math>
# <math><mrow><mo>{</mo> <mrow><mrow><mo>{</mo> <mrow><mi>x</mi> <mo>-&gt;</mo> <mtext>-1</mtext></mrow> <mo>}</mo></mrow> <mo>,</mo> <mrow><mo>{</mo> <mrow><mi>x</mi> <mo>-&gt;</mo> <mn>1</mn></mrow> <mo>}</mo></mrow></mrow> <mo>}</mo></mrow></math>

# %%
Plot[x^2, {x, 0, 1}]
# Out:
# <math><mglyph width="400px" height="247px" src="data:image/svg+xml;base64,..."/></math>
# <math><mglyph width="400px" height="247px" src="data:image/svg+xml;base64,..."/></math>
